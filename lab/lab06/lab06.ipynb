# %% [raw]
# # ASSIGNMENT CONFIG
# config_file: ../../config.yaml
# requirements: ../../requirements.txt
# overwrite_requirements: true
# name: ma4110lab06

# %% [markdown]
# # Lab 06: Examining the Therapeutic Touch
#
# Welcome to Lab 06.
#
# After such an extensive introduction to programming for data science, we are finally moving into the section of the course where we can apply our new skills to answer real questions.
#
# In this lab, we'll use testing techniques that were introduced in the lessons to test the idea of the therapeutic touch, the idea that some practitioners can feel and massage your human energy field.
#
# For all problems that you must write your explanations and sentences for, you **must** provide your answer in the designated space. Also, throughout this lab please be sure to not re-assign variables throughout the notebook. For example, if you use `expected_proportion_correct` in your answer to one question, do not reassign it later on. Moreover, be mindful that functions that you write in earlier cells will need to be referenced to answer questions in later cells.

# %% [markdown]
# <div style="background-color:#f2d8b2; border-left:6px solid #b36a00; color:#212529; padding:12px 16px; margin:8px 0; border-radius:4px;">
# <b>ℹ️ Appropriate collaboration and AI usage</b><br>
# <span style="font-size:0.9em;">You are welcome to collaborate with other students on this lab, as long as each student writes their own solutions. Consult with your teacher and course syllabus for information and policies regarding appropriate use of AI tools and submission of late work.</span>
# </div>

# %%
# Run this cell, but please don't change it.

# These lines import the Numpy and Datascience modules.
import numpy as np
from datascience import *

# These lines do some fancy plotting capabilities
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')
from matplotlib import patches
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# %% [markdown]
# ## 1. What is the Therapeutic Touch
#
# The Therapeutic Touch (TT) is the idea that everyone can feel the Human Energy Field (HEF) around individuals.  Those who practice TT have described different people's HEFs as "warm as Jell-O" and "tactile as taffy."
#
# TT was a popular technique used throughout the 20th century that was touted as a great way to bring balance to a person's health. Certain practitioners claim they have the ability to feel the HEF and can massage it in order to promote health and relaxation in individuals. The video below gives a brief overview.

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('KkXbUvU9HuI')

# %% [markdown]
# ### Emily Rosa
#
# [Emily Rosa](https://en.wikipedia.org/wiki/Emily_Rosa) was a 4th grade student who was very familiar with the world of TT, thanks to her parents, who were both medical practitioners and skeptics of TT.
#
# For her 4th grade science fair project, Emily decided to test whether or not TT practitioners could truly interact with a person's HEF. She later went on to publish her work in TT, becoming the youngest person to have a research paper published in a peer reviewed medical journal.

# %% [markdown]
# ### Emily's Experiment
#
# Emily's experiment was clean, simple, and effective. Due to her parents' occupations in the medical field, she had wide access to people who claimed to be TT practitioners.
#
# Emily took 21 TT practitioners and used them for her science experiment. She would take a TT practitioner and ask them to extend their hands through a screen (which they can't see through). Emily would randomly extend either her left hand or her right hand (using a fair coin flip to ensure it was actually random). The TT practitioner would then have to answer which hand Emily put out. If a practitioner could truly interact with a person's HEF, it would be expected that they answered correctly.
#
# Overall, through 210 samples, Emily observed that the practitioners picked the correct hand **44%** of the time.
#
# Emily's main goal here was to test whether or not the TT practitioners' guesses performed **differently** than random guesses, not better or worse. In most medical experiments, this is the norm. We want to test whether or not the treatment has an effect, **not** whether or not the treatment actually works.
#
# We will now begin to formulate this experiment in terms of the terminology we learned in this course.

# %% [raw]
# # BEGIN QUESTION
# name: q1_1
# manual: true

# %% [markdown]
# ### Question 1.1.
#
# Describe the assumptions Emily made to create her model for how likely the TT practitioners are to choose the correct hand. What would be her alternative model? Discuss with students in your group to come to a conclusion. Check in with the instructor if you are stuck.

# %% [raw]
# # BEGIN PROMPT

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:6px solid #e0a800; color:#212529; padding:12px 16px; margin:8px 0; border-radius:4px;">
# <b>✏️ YOUR TURN — replace this entire cell with your answer.</b><br>
# <span style="font-size:0.9em;">Double-click to edit, delete this box, type your response, then Shift+Enter.</span>
# </div>

# %% [raw]
# # END PROMPT

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# **SOLUTION:** Emily’s model is that the TT practitioners have a 50% chance of choosing the correct hand, like flipping a fair coin. She is trying to disprove the alternative model that the TT practitioners have some chance other than 50% of choosing the correct hand.

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_2

# %% [markdown]
# ### Question 1.2.
#
# Remember that the practitioners got the correct answer 44% (0.44) of the time.
#
# **According to Emily's model**, on average, what proportion of times do we expect the practitioner to guess the correct hand? Make sure your answer is a decimal between 0 and 1.

# %% [raw]
# # BEGIN SOLUTION

# %%
expected_proportion_correct = .5 # SOLUTION
expected_proportion_correct
# Out:
# 0.5

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `expected_proportion_correct` is a decimal between 0 and 1
failure_message: ❌ `expected_proportion_correct` is not between 0 and 1. The question asks for a proportion, not a percentage.
""" # END TEST CONFIG

0 <= expected_proportion_correct <= 1
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `expected_proportion_correct` matches Emily's model
failure_message: ❌ `expected_proportion_correct` is not what Emily's model predicts. Under her model the practitioner is guessing between two hands.
""" # END TEST CONFIG

expected_proportion_correct == 0.5
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# The goal now is to see if our deviation from this expected proportion of correct answers is due to something other than chance.

# %% [raw]
# # BEGIN QUESTION
# name: q1_3

# %% [markdown]
# ### Question 1.3.
#
# We usually use a statistic to help determine which model the evidence points towards. What is a statistic that we can use to compare outcomes under Emily’s model to what was observed? Assign `valid_stat` to an array of integer(s) representing test statistics that Emily can use:
#
# 1. The difference between the expected percent correct and the actual percent correct
# 2. The absolute difference between the expected percent correct and the actual percent correct
# 3. The sum of the expected percent correct and the actual percent correct
#
# **Hint:** Format your answer like: `valid_stat = make_array(choose one of the options listed above)`

# %% [raw]
# # BEGIN SOLUTION

# %%
valid_stat = make_array(2) # SOLUTION
valid_stat
# Out:
# array([2])

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `valid_stat` is an array
failure_message: ❌ `valid_stat` is not an array. Wrap your choice (or choices) in `make_array(...)`, even if there is only one.
""" # END TEST CONFIG

type(valid_stat) == np.ndarray
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `valid_stat` contains the right choice
failure_message: ❌ `valid_stat` does not contain the right choice. The statistic has to be large when the data disagree with the model and small when they agree, in either direction.
""" # END TEST CONFIG

int(sum(valid_stat))
# Out:
# 2

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_4
# manual: true

# %% [markdown]
# ### Question 1.4.
#
# Why is the statistic from Question 1.3 the best choice for comparing outcomes in Emily's experiment? How does it relate to the models you defined in Question 1.1?

# %% [raw]
# # BEGIN PROMPT

# %% [markdown]
# <div style="background-color:#fff3cd; border-left:6px solid #e0a800; color:#212529; padding:12px 16px; margin:8px 0; border-radius:4px;">
# <b>✏️ YOUR TURN — replace this entire cell with your answer.</b><br>
# <span style="font-size:0.9em;">Double-click to edit, delete this box, type your response, then Shift+Enter.</span>
# </div>

# %% [raw]
# # END PROMPT

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# **SOLUTION:** We want to take the absolute difference between the expected percent correct and actual percent correct because we are interested in exploring whether or not the treatment has an effect, not whether or not the treatment actually works. This is because the alternate model states that practitioners are not answering randomly, but not whether their accuracy is better or worse than if they were guessing at random.

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_5

# %% [markdown]
# ### Question 1.5.
#
# Define the function `statistic` which takes in two arguments: an expected proportion of correct guesses and an observed proportion of correct guesses collected during an experiment, and returns the value of the statistic chosen in Question 1.3. Assume that the function takes in **proportions** but returns a **percentage**. Make sure that your function returns a value between 0 and 100!

# %% [raw]
# # BEGIN SOLUTION

# %%
def statistic(expected_prop, observed_prop):
    return 100 * (np.abs(expected_prop - observed_prop)) # SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `statistic` returns the right size of difference
failure_message: ❌ `statistic` returns the wrong magnitude. It should report the difference in *percentage points*, so scale the proportion difference by 100.
""" # END TEST CONFIG

int(round(statistic(.5,.5) + statistic(.4,.1),1))
# Out:
# 30

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `statistic` gives the same answer whichever way the difference goes
failure_message: ❌ `statistic` changes when the two arguments are swapped. Take the absolute value so a difference in either direction counts the same.
""" # END TEST CONFIG

int(statistic(.4,.1) - statistic(.1,.4))
# Out:
# 0

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_6

# %% [markdown]
# ### Question 1.6.
#
# Use your `statistic` function from Question 1.5 to calculate the observed statistic from Emily's experiment. You should know what the expected proportion should be and the observed proportion the practitioners guessed correctly based on information in previous questions.

# %% [raw]
# # BEGIN SOLUTION

# %%
observed_statistic = statistic(expected_proportion_correct, .44) # SOLUTION
observed_statistic
# Out:
# 6.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `observed_statistic` has the correct value
failure_message: ❌ `observed_statistic` is not correct. Call `statistic` with the proportion Emily's model expects and the 0.44 the practitioners actually achieved.
""" # END TEST CONFIG

int(round(observed_statistic,2))
# Out:
# 6

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ### Is this observed statistic consistent with what we might see under Emily’s model?
#
# In order to answer this question, we must simulate the experiment many times using the assumptions laid out in Emily's model. If we calculate our statistic for every simulation, we can get a feel for what values of the statistic would be expected, and which almost never occur. We can then compare our observed statistic to our collection of simulated statistics to see how consistent they are.
#
# To help out, we'll learn about a new function to speed things up.

# %% [markdown]
# ### **`sample_proportions`**
#
# `sample_proportions` can be used to randomly sample from multiple categories when you know the proportion of data points that are **expected** to fall in each category. `sample_proportions` takes two arguments: the sample size and an array that contains the distribution of categories in the population (this array should sum to 1).
#
# Consider flipping a fair coin, where the two outcomes (coin lands heads and coin lands tails) occur with an equal chance. We expect that half of all coin flips will land heads, and half of all coin flips will land tails.
#
# Run the following cell to see the simulation of 10 flips of a fair coin. Let the first item of `coin_proportions` be the proportion of heads and the second item of `coin_proportions` be the proportion of tails.

# %%
expected_proportion_heads = 0.5
expected_proportion_tails = 0.5
coin_proportions = make_array(expected_proportion_heads, expected_proportion_tails) 
ten_flips = sample_proportions(10, coin_proportions)
ten_flips
# Out:
# array([ 0.6,  0.4])

# %% [markdown]
# `sample_proportions` returns an array that is the same length as the proportion array that is passed through. It contains the proportion of each category that appears in the sample.
#
# In our example, the first item of `ten_flips` is the simulated proportion of heads and the second item of `ten_flips` is the simulated proportion of tails.

# %%
simluated_proportion_heads = ten_flips.item(0)
simluated_proportion_tails = ten_flips.item(1)
print("In our simluation, " + str(simluated_proportion_heads) + " of flips were heads and " \
      + str(simluated_proportion_tails) + " of flips were tails.")
# Out:
# In our simluation, 0.6 of flips were heads and 0.4 of flips were tails.

# %% [raw]
# # BEGIN QUESTION
# name: q1_7

# %% [markdown]
# ### Question 1.7.
#
# To begin simulating, we should start by creating a representation of Emily's model to use for our simulation. This will be an array with two items in it. The first item should be the proportion of times, assuming that Emily’s model was correct, a TT practitioner picks the correct hand. The second item should be the proportion of times, under the same assumption, that the TT practitioner picks the incorrect hand. Assign `model_proportions` to this array.
#
# After this, we can simulate 210 hand choices, as Emily evaluated in real life, and find a single statistic to summarize this instance of the simulation. Use the `sample_proportions` function and assign the proportion of correct hand choices (out of 210) to `simulation_proportion_correct`. Lastly, use the `statistic` function that you wrote for Question 1.5 to assign `one_statistic`  to the value of the statistic for this one simulation.
#
# **Hint:** `sample_proportions` usage can be found [here](http://data8.org/su19/python-reference.html).

# %% [raw]
# # BEGIN SOLUTION

# %%
expected_proportion_correct = 0.5 # SOLUTION
expected_proportion_incorrect = 0.5 # SOLUTION
model_proportions = make_array(expected_proportion_correct, expected_proportion_incorrect) # SOLUTION
simulation_proportion_correct = sample_proportions(210, model_proportions).item(0) # SOLUTION
one_statistic = statistic(expected_proportion_correct, simulation_proportion_correct) # SOLUTION
one_statistic
# Out:
# 0.0

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ Emily's model gives the correct and incorrect hands the same chance
failure_message: ❌ Under Emily's model the practitioner is guessing, so picking correctly and picking incorrectly are equally likely. These two proportions should match.
""" # END TEST CONFIG

expected_proportion_correct == expected_proportion_incorrect
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ Both entries of `model_proportions` are the same
failure_message: ❌ The two entries of `model_proportions` differ. Build the array from your two proportions above, which should be equal.
""" # END TEST CONFIG

len(np.unique(model_proportions)) == 1
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `model_proportions` sums to 1, so it is a valid distribution
failure_message: ❌ `model_proportions` does not sum to 1. The two proportions have to account for every guess.
""" # END TEST CONFIG

sum(model_proportions) == 1
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `simulation_proportion_correct` is a single number
failure_message: ❌ `simulation_proportion_correct` is not a single number. `sample_proportions` returns an array — take the first item from it.
""" # END TEST CONFIG

isinstance(simulation_proportion_correct, (float, np.floating))
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `one_statistic` is in a plausible range for a simulated statistic
failure_message: ❌ `one_statistic` is outside the range we would expect. Pass the expected proportion and your simulated proportion to `statistic`.
""" # END TEST CONFIG

0 <= one_statistic <= 25
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_8

# %% [markdown]
# ### Question 1.8.
#
# Let's now see what the distribution of statistics is actually like under Emily's model.
#
# Define the function `simulation_and_statistic` which will compute a single simulated statistic. To do so, the `simulation_and_statistic` function will require two inputs: the expected **proportion** (a float between 0 and 1) that a TT practitioner would guess a hand correctly under a particular model which will be input as `expected_proportion_correct`, and an array that contains the proportions assumed will be correct and incorrect for the current model, input as `model_proportions`. The function should run one simulation which consists of Emily running 210 tests. The function should return the statistic of this one simulation.

# %% [raw]
# # BEGIN SOLUTION

# %%
def simulation_and_statistic(expected_proportion_correct, model_proportions):  
    '''Simulates 210 TT hand choices under Emily’s model.
    Returns one statistic from the simulation.'''
    # BEGIN SOLUTION
    simulated_proportion_correct = sample_proportions(210, model_proportions).item(0)
    simulated_statistic = statistic(expected_proportion_correct, simulated_proportion_correct)
    return simulated_statistic
    # END SOLUTION

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `simulation_and_statistic` returns a single number
failure_message: ❌ `simulation_and_statistic` did not return a single number. Make sure the function `return`s the statistic rather than printing it.
""" # END TEST CONFIG

isinstance(simulation_and_statistic(.5, model_proportions), (float, np.floating))
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `simulation_and_statistic` returns a plausible statistic
failure_message: ❌ `simulation_and_statistic` returned a value outside the expected range. It should simulate 210 hand choices and then call `statistic`.
""" # END TEST CONFIG

0 <= simulation_and_statistic(.5, model_proportions) <= 25
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_9

# %% [markdown]
# ### Question 1.9.
#
# Using the `simulation_and_statistics` function from Question 1.8, assign `simulated_statistics` to an array of 1000 statistics that you calculated under the assumption that Emily's model was true.

# %% [raw]
# # BEGIN SOLUTION

# %%
num_repetitions = 1000
simulated_statistics = make_array() # SOLUTION
# BEGIN SOLUTION NO PROMPT
for _ in np.arange(num_repetitions):
    one_statistic = simulation_and_statistic(expected_proportion_correct, model_proportions)
    simulated_statistics = np.append(simulated_statistics, one_statistic)
# END SOLUTION
""" # BEGIN PROMPT
for ... in ...:
    ...
"""; # END PROMPT

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `simulated_statistics` holds 1000 values
failure_message: ❌ `simulated_statistics` does not hold 1000 values. Append inside the loop rather than overwriting the array each time.
""" # END TEST CONFIG

len(simulated_statistics) == 1000
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ None of your simulated statistics are implausibly large
failure_message: ❌ At least one simulated statistic is far too large. Check that you pass proportions, not percentages, into `simulation_and_statistic`.
""" # END TEST CONFIG

np.all(simulated_statistics <= 30)
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ Every simulated statistic is non-negative
failure_message: ❌ At least one simulated statistic is negative. The statistic is an absolute difference, so it can never drop below zero.
""" # END TEST CONFIG

np.all(simulated_statistics >= 0)
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `simulation_and_statistic` still works with your own variables passed in
failure_message: ❌ `simulation_and_statistic` failed when called with `expected_proportion_correct` and `model_proportions`. The function should work for any values, not just the ones in the examples.
""" # END TEST CONFIG

0 <= simulation_and_statistic(expected_proportion_correct, model_proportions) <= 25
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# Let's view the distribution of the simulated statistics under Emily's model, and visually compare where the observed statistic lies relative to the simulated statistics.

# %%
t = Table().with_column('Simulated Statistics', simulated_statistics)
t.hist()
plots.scatter(observed_statistic, -0.01, color = 'red', s = 100);

# %% [markdown]
# We can make a visual argument as to whether we believe the observed statistic is consistent with Emily’s model. Here, since larger values of the test statistic suggest the alternative model (where the chance of guessing the correct hand is something other than 50%), we can formalize our analysis by finding what proportion of simulated statistics were as large or larger than our observed test statistic (the area at or to the right of the observed test statistic). If this area is small enough, we’ll declare that the observed data are inconsistent with our simulated model.

# %% [raw]
# # BEGIN QUESTION
# name: q1_10

# %% [markdown]
# ### Question 1.10.
#
# Calculate the proportion of simulated statistics greater than or equal to the observed statistic.

# %% [raw]
# # BEGIN SOLUTION

# %%
proportion_greater_or_equal = np.count_nonzero(simulated_statistics >= observed_statistic)/num_repetitions # SOLUTION
proportion_greater_or_equal
# Out:
# 0.074999999999999997

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `proportion_greater_or_equal` is a proportion between 0 and 1
failure_message: ❌ `proportion_greater_or_equal` is not between 0 and 1. Divide the count by the number of simulations.
""" # END TEST CONFIG

0 <= proportion_greater_or_equal <= 1
# Out:
# True

# %%
""" # BEGIN TEST CONFIG
hidden: false
success_message: ✅ `proportion_greater_or_equal` matches your simulated statistics
failure_message: ❌ `proportion_greater_or_equal` does not match your simulation. Count the simulated statistics that are greater than *or equal to* the observed one, then divide by 1000.
""" # END TEST CONFIG

proportion_greater_or_equal*1000 == np.count_nonzero(simulated_statistics >= observed_statistic)
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# By convention, we often compare the proportion we just calculated to 0.05. If the proportion of simulated statistics greater than or equal to the observed statistic is sufficiently small (less than or equal to 0.05), then this is evidence against Emily's model. Otherwise, we don’t have any reason to doubt Emily’s model.
#
# This should help you make your own conclusions about Emily Rosa's experiment.

# %% [raw]
# # BEGIN QUESTION
# name: q1_11
# manual: true

# %% [markdown]
# ### Question 1.11.
#
# Does the proportion calculated in Question 1.10 suggest that there is sufficient evidence to reject Emily's model (that TT practitioners are effectively guessing)?

# %% [raw]
# # BEGIN SOLUTION

# %% [markdown]
# **SOLUTION:** The data are more consistent with Emily's model (practitioners were randomly guessing). The area of the histogram to the right of the observed statistic is not sufficiently small: it is not below 5%. Furthermore, the proportion of simulated statistics greater than the observed statistic is greater than 0.05, which suggests there is not enough evidence against Emily's model.

# %% [raw]
# # END SOLUTION

# %% [raw]
# # END QUESTION

# %% [markdown]
# Therapeutic touch fell out of use after this experiment, which was eventually accepted into one of the premier medical journals. TT practitioners responded and accused Emily and her family of tampering with the results, while some claimed that Emily's bad spiritual mood towards therapeutic touch made it difficult to read her HEF. Whatever it may be, Emily's experiment is a classic example of how anyone, with the right resources, can test anything they want.

# %% [markdown]
# # Submitting your work
# You're done with this assignment! Assignments should be turned in using the following best practices:
# 1. Save your notebook.
# 2. Restart the kernel and run all cells up to this one.
# 3. Run the cell below with the code `grader.export(...)`. This will re-run all the tests. Make sure they are passing as you expect them to.
# 4. Download the file named `lab06_<date-time-stamp>.zip`, found in the explorer pane on the left side of the screen. **Note**: If clicking on the link in this notebook results in an error, try downloading the file from the file explorer panel on the left.
# 5. Upload `lab06_<date-time-stamp>.zip` to the corresponding assignment on Canvas.
